# %% [markdown]
# # StatsBomb Data Exploration
# Pull competitions, matches, events, and 360° freeze frames from StatsBomb open data.

# %%
from statsbombpy import sb
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 60)

# %% [markdown]
# ## 1. Available Competitions

# %%
competitions = sb.competitions()
print(f"Total competitions available: {len(competitions)}")
competitions[['competition_id', 'season_id', 'competition_name', 'country_name', 'season_name', 'competition_gender']]
# Out:
# Total competitions available: 75
#     competition_id  season_id        competition_name   country_name  \
# 0                9        281           1. Bundesliga        Germany
# 1                9         27           1. Bundesliga        Germany
# 2             1267        107  African Cup of Nations         Africa
# 3               16          4        Champions League         Europe
# 4               16          1        Champions League         Europe
# ..             ...        ...                     ...            ...
# 70              35         75      UEFA Europa League         Europe
# 71              53        315       UEFA Women's Euro         Europe
# 72              53        106       UEFA Women's Euro         Europe
# 73              72        107       Women's World Cup  International
# 74              72         30       Women's World Cup  International
#
#    season_name competition_gender
# 0    2023/2024               male
# 1    2015/2016               male
# 2         2023               male
# 3    2018/2019               male
# 4    2017/2018               male
# ..         ...                ...
# 70   1988/1989               male
# 71        2025             female
# 72        2022             female
# 73        2023             female
# 74        2019             female
#
# [75 rows x 6 columns]

# %% [markdown]
# ## 2. Matches — pick a competition
#
# Change `COMPETITION_ID` and `SEASON_ID` to explore different datasets.
#
# | Competition | competition_id | season_id |
# |---|---|---|
# | La Liga 2020/21 | 11 | 90 |
# | FIFA World Cup 2022 | 43 | 106 |
# | NWSL 2018 | 49 | 3 |
# | Women's World Cup 2019 | 72 | 30 |

# %%
COMPETITION_ID = 43   # La Liga
SEASON_ID = 106      # 2020/21

matches = sb.matches(competition_id=COMPETITION_ID, season_id=SEASON_ID)
print(f"Matches found: {len(matches)}")
matches[['match_id', 'match_date', 'home_team', 'away_team', 'home_score', 'away_score', 'stadium', 'referee']].head(10)
# Out:
# Matches found: 64
#    match_id  match_date    home_team    away_team  home_score  away_score  \
# 0   3857256  2022-12-02       Serbia  Switzerland           2           3
# 1   3869151  2022-12-03    Argentina    Australia           2           1
# 2   3857257  2022-11-30    Australia      Denmark           1           0
# 3   3857258  2022-11-24       Brazil       Serbia           2           0
# 4   3857288  2022-11-26      Tunisia    Australia           0           1
# 5   3857267  2022-11-29      Ecuador      Senegal           1           2
# 6   3869321  2022-12-09  Netherlands    Argentina           2           2
# 7   3857287  2022-11-24      Uruguay  South Korea           0           0
# 8   3869486  2022-12-10      Morocco     Portugal           1           0
# 9   3869685  2022-12-18    Argentina       France           3           3
#
#                                 stadium                     referee
# 0                           Stadium 974   Fernando Andrés Rapallini
# 1                 Ahmad bin Ali Stadium            Szymon Marciniak
# 2                  Al Janoub Stadium               Mustapha Ghorbal
# 3                        Lusail Stadium             Alireza Faghani
# 4                  Al Janoub Stadium                 Daniel Siebert
# 5  Sheikh Khalifa International Stadium              Clément Turpin
# 6                        Lusail Stadium  Antonio Miguel Mateu Lahoz
# 7               Education City Stadium               Clément Turpin
# 8                    Al Thumama Stadium      Facundo Tello Figueroa
# 9                        Lusail Stadium            Szymon Marciniak

# %% [markdown]
# ## 3. Events for a single match

# %%
MATCH_ID = matches['match_id'].iloc[0]
print(f"Loading events for match_id: {MATCH_ID}")

events = sb.events(match_id=MATCH_ID)
print(f"Total events: {len(events)}")
print(f"Columns: {list(events.columns)}")
events.head(10)
# Out:
# Loading events for match_id: 3857256
# /Users/adarshkasula/Documents/Applications/anaconda3/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Total events: 3211
# Columns: ['bad_behaviour_card', 'ball_receipt_outcome', 'ball_recovery_recovery_failure', 'block_deflection', 'block_offensive', 'carry_end_location', 'clearance_aerial_won', 'clearance_body_part', 'clearance_head', 'clearance_left_foot', 'clearance_right_foot', 'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage', 'foul_committed_card', 'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive', 'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome', 'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id', 'index', 'injury_stoppage_in_chain', 'interception_outcome', 'location', 'match_id', 'minute', 'off_camera', 'out', 'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id', 'pass_body_part', 'pass_cross', 'pass_cut_back', 'pass_deflected', 'pass_end_location', 'pass_goal_assist', 'pass_height', 'pass_length', 'pass_miscommunication', 'pass_outcome', 'pass_outswinging', 'pass_recipient', 'pass_recipient_id', 'pass_shot_assist', 'pass_switch', 'pass_technique', 'pass_through_ball', 'pass_type', 'period', 'play_pattern', 'player', 'player_id', 'position', 'possession', 'possession_team', 'possession_team_id', 'related_events', 'second', 'shot_aerial_won', 'shot_body_part', 'shot_deflected', 'shot_end_location', 'shot_first_time', 'shot_freeze_frame', 'shot_key_pass_id', 'shot_one_on_one', 'shot_open_goal', 'shot_outcome', 'shot_statsbomb_xg', 'shot_technique', 'shot_type', 'substitution_outcome', 'substitution_outcome_id', 'substitution_replacement', 'substitution_replacement_id', 'tactics', 'team', 'team_id', 'timestamp', 'type', 'under_pressure']
#   bad_behaviour_card ball_receipt_outcome ball_recovery_recovery_failure  \
# 0                NaN                  NaN                            NaN
# 1                NaN                  NaN                            NaN
# 2                NaN                  NaN                            NaN
# 3                NaN                  NaN                            NaN
# 4                NaN                  NaN                            NaN
# 5                NaN                  NaN                            NaN
# 6                NaN                  NaN                            NaN
# 7                NaN                  NaN                            NaN
# 8                NaN                  NaN                            NaN
# 9                NaN                  NaN                            NaN
#
#   block_deflection block_offensive carry_end_location clearance_aerial_won  \
# 0              NaN             NaN                NaN                  NaN
# 1              NaN             NaN                NaN                  NaN
# 2              NaN             NaN                NaN                  NaN
# 3              NaN             NaN                NaN                  NaN
# 4              NaN             NaN                NaN                  NaN
# 5              NaN             NaN                NaN                  NaN
# 6              NaN             NaN                NaN                  NaN
# 7              NaN             NaN                NaN                  NaN
# 8              NaN             NaN                NaN                  NaN
# 9              NaN             NaN                NaN                  NaN
#
#   clearance_body_part clearance_head clearance_left_foot clearance_right_foot  \
# 0                 NaN            NaN                 NaN                  NaN
# 1                 NaN            NaN                 NaN                  NaN
# 2                 NaN            NaN                 NaN                  NaN
# 3                 NaN            NaN                 NaN                  NaN
# 4                 NaN            NaN                 NaN                  NaN
# 5                 NaN            NaN                 NaN                  NaN
# 6                 NaN            NaN                 NaN                  NaN
# 7                 NaN            NaN                 NaN                  NaN
# 8                 NaN            NaN                 NaN                  NaN
# 9                 NaN            NaN                 NaN                  NaN
#
#   counterpress dribble_nutmeg dribble_outcome duel_outcome duel_type  \
# 0          NaN            NaN             NaN          NaN       NaN
# 1          NaN            NaN             NaN          NaN       NaN
# 2          NaN            NaN             NaN          NaN       NaN
# 3          NaN            NaN             NaN          NaN       NaN
# 4          NaN            NaN             NaN          NaN       NaN
# 5          NaN            NaN             NaN          NaN       NaN
# 6          NaN            NaN             NaN          NaN       NaN
# 7          NaN            NaN             NaN          NaN       NaN
# 8          NaN            NaN             NaN          NaN       NaN
# 9          NaN            NaN             NaN          NaN       NaN
#
#    duration foul_committed_advantage foul_committed_card foul_committed_type  \
# 0  0.000000                      NaN                 NaN                 NaN
# 1  0.000000                      NaN                 NaN                 NaN
# 2  0.000000                      NaN                 NaN                 NaN
# 3  0.000000                      NaN                 NaN                 NaN
# 4  0.000000                      NaN                 NaN                 NaN
# 5  0.000000                      NaN                 NaN                 NaN
# 6  1.220932                      NaN                 NaN                 NaN
# 7  1.752177                      NaN                 NaN                 NaN
# 8  1.787088                      NaN                 NaN                 NaN
# 9  5.037477                      NaN                 NaN                 NaN
#
#   foul_won_advantage foul_won_defensive goalkeeper_body_part  \
# 0                NaN                NaN                  NaN
# 1                NaN                NaN                  NaN
# 2                NaN                NaN                  NaN
# 3                NaN                NaN                  NaN
# 4                NaN                NaN                  NaN
# 5                NaN                NaN                  NaN
# 6                NaN                NaN                  NaN
# 7                NaN                NaN                  NaN
# 8                NaN                NaN                  NaN
# 9                NaN                NaN                  NaN
#
#   goalkeeper_end_location goalkeeper_outcome goalkeeper_position  \
# 0                     NaN                NaN                 NaN
# 1                     NaN                NaN                 NaN
# 2                     NaN                NaN                 NaN
# 3                     NaN                NaN                 NaN
# 4                     NaN                NaN                 NaN
# 5                     NaN                NaN                 NaN
# 6                     NaN                NaN                 NaN
# 7                     NaN                NaN                 NaN
# 8                     NaN                NaN                 NaN
# 9                     NaN                NaN                 NaN
#
#   goalkeeper_technique goalkeeper_type                                    id  \
# 0                  NaN             NaN  093f898d-33b1-4425-b591-37dd9c9bf70b
# 1                  NaN             NaN  79a9efbb-b5e5-45b0-983d-8729bcc4a0e1
# 2                  NaN             NaN  c4cdfc71-b9f4-4751-a714-e816c1419457
# 3                  NaN             NaN  51f295b8-da96-428e-ab47-90f380f8cf53
# 4                  NaN             NaN  749a27ed-92e8-4723-9ac5-dcd074535537
# 5                  NaN             NaN  f6a97503-ed87-4a13-89ba-8c4bbccc6686
# 6                  NaN             NaN  4acb4fd2-f46a-4d73-993c-e06597873924
# 7                  NaN             NaN  f21fda3d-cb2c-4608-af2d-201d1ad8101c
# 8                  NaN             NaN  57654ce3-e311-49c4-9ba7-4fab2ec66f71
# 9                  NaN             NaN  b4fc9de7-9029-4f18-bd6c-3d2a3c5e276a
#
#    index injury_stoppage_in_chain interception_outcome      location  \
# 0      1                      NaN                  NaN           NaN
# 1      2                      NaN                  NaN           NaN
# 2      3                      NaN                  NaN           NaN
# 3      4                      NaN                  NaN           NaN
# 4   1516                      NaN                  NaN           NaN
# 5   1517                      NaN                  NaN           NaN
# 6      5                      NaN                  NaN  [61.0, 40.1]
# 7      8                      NaN                  NaN  [39.7, 45.5]
# 8     11                      NaN                  NaN  [42.3, 72.2]
# 9     13                      NaN                  NaN  [23.1, 62.4]
#
#    match_id  minute off_camera  out pass_aerial_won  pass_angle  \
# 0   3857256       0        NaN  NaN             NaN         NaN
# 1   3857256       0        NaN  NaN             NaN         NaN
# 2   3857256       0        NaN  NaN             NaN         NaN
# 3   3857256       0        NaN  NaN             NaN         NaN
# 4   3857256      45        NaN  NaN             NaN         NaN
# 5   3857256      45        NaN  NaN             NaN         NaN
# 6   3857256       0        NaN  NaN             NaN    2.943123
# 7   3857256       0        NaN  NaN             NaN    1.473724
# 8   3857256       0        NaN  NaN             NaN   -2.669646
# 9   3857256       0        NaN  NaN             NaN    0.203045
#
#   pass_assisted_shot_id pass_body_part pass_cross pass_cut_back  \
# 0                   NaN            NaN        NaN           NaN
# 1                   NaN            NaN        NaN           NaN
# 2                   NaN            NaN        NaN           NaN
# 3                   NaN            NaN        NaN           NaN
# 4                   NaN            NaN        NaN           NaN
# 5                   NaN            NaN        NaN           NaN
# 6                   NaN     Right Foot        NaN           NaN
# 7                   NaN     Right Foot        NaN           NaN
# 8                   NaN     Right Foot        NaN           NaN
# 9                   NaN     Right Foot        NaN           NaN
#
#   pass_deflected pass_end_location pass_goal_assist  pass_height  pass_length  \
# 0            NaN               NaN              NaN          NaN          NaN
# 1            NaN               NaN              NaN          NaN          NaN
# 2            NaN               NaN              NaN          NaN          NaN
# 3            NaN               NaN              NaN          NaN          NaN
# 4            NaN               NaN              NaN          NaN          NaN
# 5            NaN               NaN              NaN          NaN          NaN
# 6            NaN      [43.1, 43.7]              NaN  Ground Pass    18.258423
# 7            NaN      [42.3, 72.2]              NaN  Ground Pass    26.826294
# 8            NaN      [23.1, 62.4]              NaN  Ground Pass    21.556438
# 9            NaN      [91.1, 76.4]              NaN    High Pass    69.426216
#
#   pass_miscommunication pass_outcome pass_outswinging      pass_recipient  \
# 0                   NaN          NaN              NaN                 NaN
# 1                   NaN          NaN              NaN                 NaN
# 2                   NaN          NaN              NaN                 NaN
# 3                   NaN          NaN              NaN                 NaN
# 4                   NaN          NaN              NaN                 NaN
# 5                   NaN          NaN              NaN                 NaN
# 6                   NaN          NaN              NaN        Remo Freuler
# 7                   NaN          NaN              NaN       Silvan Widmer
# 8                   NaN          NaN              NaN  Fabian Lukas Schär
# 9                   NaN          NaN              NaN         Djibril Sow
#
#    pass_recipient_id pass_shot_assist pass_switch pass_technique  \
# 0                NaN              NaN         NaN            NaN
# 1                NaN              NaN         NaN            NaN
# 2                NaN              NaN         NaN            NaN
# 3                NaN              NaN         NaN            NaN
# 4                NaN              NaN         NaN            NaN
# 5                NaN              NaN         NaN            NaN
# 6             6983.0              NaN         NaN            NaN
# 7             7796.0              NaN         NaN            NaN
# 8             5537.0              NaN         NaN            NaN
# 9            16026.0              NaN         NaN            NaN
#
#   pass_through_ball pass_type  period   play_pattern               player  \
# 0               NaN       NaN       1   Regular Play                  NaN
# 1               NaN       NaN       1   Regular Play                  NaN
# 2               NaN       NaN       1   Regular Play                  NaN
# 3               NaN       NaN       1   Regular Play                  NaN
# 4               NaN       NaN       2   Regular Play                  NaN
# 5               NaN       NaN       2   Regular Play                  NaN
# 6               NaN  Kick Off       1  From Kick Off  Breel-Donald Embolo
# 7               NaN       NaN       1  From Kick Off         Remo Freuler
# 8               NaN       NaN       1  From Kick Off        Silvan Widmer
# 9               NaN       NaN       1  From Kick Off   Fabian Lukas Schär
#
#    player_id                  position  possession possession_team  \
# 0        NaN                       NaN           1          Serbia
# 1        NaN                       NaN           1          Serbia
# 2        NaN                       NaN           1          Serbia
# 3        NaN                       NaN           1          Serbia
# 4        NaN                       NaN         107     Switzerland
# 5        NaN                       NaN         107     Switzerland
# 6     5545.0            Center Forward           2     Switzerland
# 7     6983.0  Right Defensive Midfield           2     Switzerland
# 8     7796.0                Right Back           2     Switzerland
# 9     5537.0         Right Center Back           2     Switzerland
#
#    possession_team_id                          related_events  second  \
# 0                 786                                     NaN       0
# 1                 786                                     NaN       0
# 2                 786  [51f295b8-da96-428e-ab47-90f380f8cf53]       0
# 3                 786  [c4cdfc71-b9f4-4751-a714-e816c1419457]       0
# 4                 773  [f6a97503-ed87-4a13-89ba-8c4bbccc6686]       0
# 5                 773  [749a27ed-92e8-4723-9ac5-dcd074535537]       0
# 6                 773  [b0d0583a-d544-4ab1-9043-6b42a57c27a8]       0
# 7                 773  [c2ce6157-3b39-4a0e-b63f-3178874e1cf4]       3
# 8                 773  [e12a759e-24cc-49f4-baec-7435b52965fe]       6
# 9                 773  [59c636fa-6894-4673-993d-262f379dacac]       8
#
#   shot_aerial_won shot_body_part shot_deflected shot_end_location  \
# 0             NaN            NaN            NaN               NaN
# 1             NaN            NaN            NaN               NaN
# 2             NaN            NaN            NaN               NaN
# 3             NaN            NaN            NaN               NaN
# 4             NaN            NaN            NaN               NaN
# 5             NaN            NaN            NaN               NaN
# 6             NaN            NaN            NaN               NaN
# 7             NaN            NaN            NaN               NaN
# 8             NaN            NaN            NaN               NaN
# 9             NaN            NaN            NaN               NaN
#
#   shot_first_time shot_freeze_frame shot_key_pass_id shot_one_on_one  \
# 0             NaN               NaN              NaN             NaN
# 1             NaN               NaN              NaN             NaN
# 2             NaN               NaN              NaN             NaN
# 3             NaN               NaN              NaN             NaN
# 4             NaN               NaN              NaN             NaN
# 5             NaN               NaN              NaN             NaN
# 6             NaN               NaN              NaN             NaN
# 7             NaN               NaN              NaN             NaN
# 8             NaN               NaN              NaN             NaN
# 9             NaN               NaN              NaN             NaN
#
#   shot_open_goal shot_outcome  shot_statsbomb_xg shot_technique shot_type  \
# 0            NaN          NaN                NaN            NaN       NaN
# 1            NaN          NaN                NaN            NaN       NaN
# 2            NaN          NaN                NaN            NaN       NaN
# 3            NaN          NaN                NaN            NaN       NaN
# 4            NaN          NaN                NaN            NaN       NaN
# 5            NaN          NaN                NaN            NaN       NaN
# 6            NaN          NaN                NaN            NaN       NaN
# 7            NaN          NaN                NaN            NaN       NaN
# 8            NaN          NaN                NaN            NaN       NaN
# 9            NaN          NaN                NaN            NaN       NaN
#
#   substitution_outcome  substitution_outcome_id substitution_replacement  \
# 0                  NaN                      NaN                      NaN
# 1                  NaN                      NaN                      NaN
# 2                  NaN                      NaN                      NaN
# 3                  NaN                      NaN                      NaN
# 4                  NaN                      NaN                      NaN
# 5                  NaN                      NaN                      NaN
# 6                  NaN                      NaN                      NaN
# 7                  NaN                      NaN                      NaN
# 8                  NaN                      NaN                      NaN
# 9                  NaN                      NaN                      NaN
#
#    substitution_replacement_id  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
#
#                                                        tactics         team  \
# 0  {'formation': 3412, 'lineup': [{'player': {'id': 20600, ...       Serbia
# 1  {'formation': 4231, 'lineup': [{'player': {'id': 17974, ...  Switzerland
# 2                                                          NaN  Switzerland
# 3                                                          NaN       Serbia
# 4                                                          NaN       Serbia
# 5                                                          NaN  Switzerland
# 6                                                          NaN  Switzerland
# 7                                                          NaN  Switzerland
# 8                                                          NaN  Switzerland
# 9                                                          NaN  Switzerland
#
#    team_id     timestamp         type under_pressure
# 0      786  00:00:00.000  Starting XI            NaN
# 1      773  00:00:00.000  Starting XI            NaN
# 2      773  00:00:00.000   Half Start            NaN
# 3      786  00:00:00.000   Half Start            NaN
# 4      786  00:00:00.000   Half Start            NaN
# 5      773  00:00:00.000   Half Start            NaN
# 6      773  00:00:00.521         Pass            NaN
# 7      773  00:00:03.385         Pass            NaN
# 8      773  00:00:06.697         Pass            NaN
# 9      773  00:00:08.484         Pass            NaN

# %% [markdown]
# ## 4. Event type breakdown

# %%
# Extract type name from the nested dict
events['type_name'] = events['type'].apply(lambda t: t['name'] if isinstance(t, dict) else t)
events['type_name'].value_counts()
# Out:
# type_name
# Pass                 1118
# Ball Receipt*        1059
# Carry                 888
# Pressure              307
# Ball Recovery          99
# Duel                   63
# Dribble                40
# Block                  39
# Clearance              39
# Goal Keeper            35
# Dispossessed           29
# Shot                   29
# Miscontrol             26
# Foul Won               26
# Foul Committed         26
# Dribbled Past          26
# Interception           14
# Substitution           10
# Half Start              4
# Half End                4
# Referee Ball-Drop       2
# Starting XI             2
# 50/50                   2
# Bad Behaviour           1
# Injury Stoppage         1
# Tactical Shift          1
# Error                   1
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Ball locations (passes + carries)

# %%
pass_carry = events[events['type_name'].isin(['Pass', 'Carry'])].copy()
pass_carry['ball_x'] = pass_carry['location'].apply(lambda l: l[0] if isinstance(l, list) else None)
pass_carry['ball_y'] = pass_carry['location'].apply(lambda l: l[1] if isinstance(l, list) else None)

pass_carry[['index', 'type_name', 'ball_x', 'ball_y', 'possession', 'team', 'player']].head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Applications/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 pass_carry = events[events['type_name'].isin(['Pass', 'Carry'])].copy()
#       2 pass_carry['ball_x'] = pass_carry['location'].apply(lambda l: l[0] if isinstance(l, list) else None)
#       3 pass_carry['ball_y'] = pass_carry['location'].apply(lambda l: l[1] if isinstance(l, list) else None)
#
# File ~/Documents/Applications/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/Documents/Applications/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'type_name'

# %%
shots = events[events['type_name'] == 'Shot'].copy()

# statsbombpy flattens nested dicts into prefixed columns (shot_outcome, shot_statsbomb_xg, etc.)
# Extract outcome name — stored as a dict or already a string depending on version
if 'shot_outcome' in shots.columns:
    shots['shot_outcome'] = shots['shot_outcome'].apply(
        lambda s: s.get('name', '') if isinstance(s, dict) else str(s) if pd.notna(s) else ''
    )
else:
    shots['shot_outcome'] = ''

if 'shot_statsbomb_xg' in shots.columns:
    shots['xg'] = shots['shot_statsbomb_xg']
else:
    shots['xg'] = None

shots['ball_x'] = shots['location'].apply(lambda l: l[0] if isinstance(l, list) else None)
shots['ball_y'] = shots['location'].apply(lambda l: l[1] if isinstance(l, list) else None)

print(f"Total shots: {len(shots)}")
shots[['player', 'team', 'ball_x', 'ball_y', 'xg', 'shot_outcome']].sort_values('xg', ascending=False)
# Out:
# Total shots: 29
#                                                 player              team  \
# 3809                         Luis Jesús Rioja González  Deportivo Alavés
# 3818                                 Antoine Griezmann         Barcelona
# 3810                                   Frenkie de Jong         Barcelona
# 3805                                    Anssumane Fati         Barcelona
# 3830                             Gerard Piqué Bernabéu         Barcelona
# 3813                    Lionel Andrés Messi Cuccittini         Barcelona
# 3829                             Gerard Piqué Bernabéu         Barcelona
# 3807                                 Antoine Griezmann         Barcelona
# 3806                       Edgar Antonio Méndez Ortega  Deportivo Alavés
# 3811                    Lionel Andrés Messi Cuccittini         Barcelona
# 3816                                    Anssumane Fati         Barcelona
# 3808                    Lionel Andrés Messi Cuccittini         Barcelona
# 3819                    Lionel Andrés Messi Cuccittini         Barcelona
# 3827                                      Sergino Dest         Barcelona
# 3833                    Lionel Andrés Messi Cuccittini         Barcelona
# 3814                    Lionel Andrés Messi Cuccittini         Barcelona
# 3832                    Lionel Andrés Messi Cuccittini         Barcelona
# 3822                                    Anssumane Fati         Barcelona
# 3820                                    Miralem Pjanić         Barcelona
# 3817                    Lionel Andrés Messi Cuccittini         Barcelona
# 3824  Francisco António Machado Mota de Castro Trincão         Barcelona
# 3821                          José Luis Sanmartín Mato  Deportivo Alavés
# 3825  Francisco António Machado Mota de Castro Trincão         Barcelona
# 3823                                    Anssumane Fati         Barcelona
# 3815                    Lionel Andrés Messi Cuccittini         Barcelona
# 3831                    Lionel Andrés Messi Cuccittini         Barcelona
# 3826                                      Sergino Dest         Barcelona
# 3828                                    Miralem Pjanić         Barcelona
# 3812                   Florian Grégoire Claude Lejeune  Deportivo Alavés
#
#       ball_x  ball_y        xg shot_outcome
# 3809   118.3    42.1  0.976192         Goal
# 3818   107.6    31.3  0.291415         Goal
# 3810   113.1    39.3  0.203073        Off T
# 3805   108.6    28.0  0.200969        Off T
# 3830   108.9    44.1  0.152962        Off T
# 3813   105.3    32.9  0.112452        Saved
# 3829   114.5    46.0  0.104497      Blocked
# 3807   104.3    33.9  0.098879        Off T
# 3806   103.6    51.0  0.096384        Saved
# 3811   101.3    41.6  0.095015      Blocked
# 3816   111.5    31.6  0.085421        Off T
# 3808    97.9    44.3  0.078938      Blocked
# 3819   108.4    49.5  0.077940        Saved
# 3827   106.4    49.8  0.064203        Saved
# 3833   104.9    49.8  0.063644        Off T
# 3814   113.3    26.1  0.054103        Saved
# 3832    99.0    46.8  0.051499      Blocked
# 3822   103.2    35.7  0.051461      Blocked
# 3820    98.2    34.7  0.048743        Off T
# 3817    99.0    24.7  0.044592        Off T
# 3824    96.4    46.8  0.038860      Blocked
# 3821   106.6    35.3  0.038184        Saved
# 3825    97.5    49.6  0.037237      Blocked
# 3823   103.4    24.7  0.034161        Saved
# 3815   107.4    27.2  0.030959        Saved
# 3831    94.0    49.1  0.027491      Blocked
# 3826    92.9    28.0  0.021675      Blocked
# 3828    88.7    39.7  0.020938        Saved
# 3812    84.7    42.1  0.017764        Off T

# %% [markdown]
# ## 7. 360° Freeze Frames

# %%
# NOTE: 360° freeze frames only exist for select competitions.
# Competitions with 360 data: FIFA World Cup 2022 (43/106), UEFA Euro 2020 (55/43),
# Women's World Cup 2023 (72/107), UEFA Women's Euro 2022 (53/106)
#
# La Liga (competition_id=11) does NOT have 360 data.
# Switch to a supported competition to see freeze frames.

MATCH_ID_360 = matches['match_id'].iloc[0]  # update if using a different competition

try:
    frames = sb.frames(match_id=MATCH_ID_360)
except Exception as e:
    print(f"Error fetching frames: {e}")
    frames = None

if frames is not None and not frames.empty:
    print(f"Freeze frame rows: {len(frames)}")
    print(f"Columns: {list(frames.columns)}")

    # location may already be exploded into x/y in newer statsbombpy versions
    if 'location' in frames.columns:
        frames['x'] = frames['location'].apply(lambda l: l[0] if isinstance(l, list) else None)
        frames['y'] = frames['location'].apply(lambda l: l[1] if isinstance(l, list) else None)
        frames = frames.drop(columns=['location'])

    display(frames.head(20))
else:
    print("No 360 freeze frames for this match.")
    print("To get freeze frames, use FIFA World Cup 2022:")
    print("  competition_id = 43, season_id = 106")
    print("Then update MATCH_ID_360 with a match_id from that competition.")
# Out:
# Error fetching frames: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/statsbomb/open-data/master/data/three-sixty/3773386.json
# No 360 freeze frames for this match.
# To get freeze frames, use FIFA World Cup 2022:
#   competition_id = 43, season_id = 106
# Then update MATCH_ID_360 with a match_id from that competition.

# %% [markdown]
# ## 8. Single freeze frame — player positions for one shot

# %%
if frames is not None and not frames.empty and len(shots) > 0:
    top_shot_id = shots.sort_values('xg', ascending=False).iloc[0]['id']
    shot_frame = frames[frames['id'] == top_shot_id]
    print(f"Players in freeze frame for highest-xG shot (event {top_shot_id}):")
    print(shot_frame[['teammate', 'actor', 'keeper', 'x', 'y']])
else:
    print("No freeze frames available for this match.")

# %% [markdown]
# ## 9. Quick pitch plot — shot locations

# %%
import matplotlib.pyplot as plt
from mplsoccer import Pitch

pitch = Pitch(pitch_type='statsbomb', pitch_color='grass', line_color='white')
fig, ax = pitch.draw(figsize=(12, 8))

goals = shots[shots['shot_outcome'] == 'Goal']
non_goals = shots[shots['shot_outcome'] != 'Goal']

pitch.scatter(non_goals['ball_x'], non_goals['ball_y'], ax=ax,
              s=non_goals['xg'] * 500 + 50, color='white', edgecolors='grey',
              alpha=0.7, label='No Goal')
pitch.scatter(goals['ball_x'], goals['ball_y'], ax=ax,
              s=goals['xg'] * 500 + 50, color='red', edgecolors='darkred',
              alpha=0.9, label='Goal')

ax.legend(loc='upper left', fontsize=12)
ax.set_title(f'Shot Map — Match {MATCH_ID}  (bubble size = xG)', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Save raw data to parquet

# %%
from pathlib import Path

raw_dir = Path('../data/raw')
raw_dir.mkdir(parents=True, exist_ok=True)

events.to_parquet(raw_dir / f'events_{MATCH_ID}.parquet', index=False)
print(f"Saved events_{MATCH_ID}.parquet")

if frames is not None and not frames.empty:
    frames.to_parquet(raw_dir / f'frames_{MATCH_ID}.parquet', index=False)
    print(f"Saved frames_{MATCH_ID}.parquet")

print("Done. Files in data/raw/:")
for f in sorted(raw_dir.iterdir()):
    print(f"  {f.name}  ({f.stat().st_size / 1024:.1f} KB)")
